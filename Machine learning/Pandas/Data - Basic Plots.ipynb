# %% [markdown]
# # Plots y visualización de los datos

# %%
#Líbrerias
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#DATA
data = pd.read_csv("Customer Churn Model.txt")

# %%
#Al usar notebook
% matplotlib inline

# %%
#Guardar un plot directamente
#savefig("path_donde_guardar_im.jpeg" png.. etc)

# %% [markdown]
# ### Scatter Plot

# %%
data.plot(kind = "scatter", x = "Day Mins", y = "Day Charge")

# %%
data.plot(kind = "scatter", x = "Night Mins", y = "Night Charge")

# %%
#figure para hacer los graficos
#axs para los ejes

figure, axs = plt.subplots(2,2,sharey = True,sharex = True)
data.plot(kind = "scatter", x = "Day Mins", y = "Day Charge", ax = axs[0][0])
data.plot(kind = "scatter", x = "Night Mins", y = "Night Charge", ax = axs[0][1])
data.plot(kind = "scatter", x = "Day Calls", y = "Day Charge", ax = axs[1][0])
data.plot(kind = "scatter", x = "Night Calls", y = "Night Charge", ax = axs[1][1])

# %% [markdown]
# ### Histogramas de frecuencias

# %%
plt.hist(data["Day Calls"], bins = [0,30,60,90,120,150,180])
plt.xlabel("Número de llamadas al día")
plt.ylabel("Frecuencia")
plt.title("Histograma del número de llamadas al día")
# Out:
# Text(0.5,1,'Histograma del número de llamadas al día')

# %%
#APLICAR REGLA DE STURJES PARA SABER EN CUANTO DIVIDIR NUESTRO HISTOGRAMA
k = int(np.ceil(1+np.log2(3333)))
plt.hist(data["Day Calls"], bins = k)
plt.xlabel("Número de llamadas al día")
plt.ylabel("Frecuencia")
plt.title("Histograma del número de llamadas al día")
# Out:
# Text(0.5,1,'Histograma del número de llamadas al día')

# %% [markdown]
# ## Boxplot, diagrama de caja y bigotes

# %%
plt.boxplot(data["Day Calls"])
plt.ylabel("Número de llamadas diaras")
plt.xlabel("Bloxplot de las llamadas diarias")
plt.title("Bloxplot de las llamadas diarias")
# Out:
# Text(0.5,1,'Bloxplot de las llamadas diarias')

# %%
data["Day Calls"].describe()
# Out:
# count    3333.000000
# mean      100.435644
# std        20.069084
# min         0.000000
# 25%        87.000000
# 50%       101.000000
# 75%       114.000000
# max       165.000000
# Name: Day Calls, dtype: float64

# %%
#Rango intercuartilico
iqr = data["Day Calls"].quantile(0.75) - data["Day Calls"].quantile(0.25)
iqr
# Out:
# 27.0

# %%
#Donde termina el bigote inferior del boxplot
data["Day Calls"].quantile(0.25) - 1.5 * iqr
# Out:
# 46.5

# %%
#Donde termina el bigote superior del boxplot
data["Day Calls"].quantile(0.75) + 1.5 * iqr
# Out:
# 154.5
